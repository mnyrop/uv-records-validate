# %%
# from invenio_rdm_records import records as rdm_records
# record = rdm_records.api.RDMRecord
# vars(record)

import json
import jsonschema

# %%
schema_file = './schemas/record-schema-old.json'
record_file = './data/UC-01.json'

schema      = json.load(open(schema_file))
record      = json.load(open(record_file))

jsonschema.validate(instance=record, schema=schema)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# /var/folders/h2/m7_vrgx173s3jj_df504j1sc0000gp/T/ipykernel_7157/2503368869.py in <module>
#       5 record      = json.load(open(record_file))
#       6
# ----> 7 jsonschema.validate(instance=record, schema=schema)
#
# ~/.local/share/virtualenvs/uv-records-lint-poI6SsbF/lib/python3.9/site-packages/jsonschema/validators.py in validate(instance, schema, cls, *args, **kwargs)
#     961         cls = validator_for(schema)
#     962
# --> 963     cls.check_schema(schema)
#     964     validator = cls(schema, *args, **kwargs)
#     965     error = exceptions.best_match(validator.iter_errors(instance))
#
# ~/.local/share/virtualenvs/uv-records-lint-poI6SsbF/lib/python3.9/site-packages/jsonschema/validators.py in check_schema(cls, schema)
#     181         def check_schema(cls, schema):
# ...

# %%
schema
# Out:
# {'$schema': 'http://json-schema.org/draft-05/schema#',
#  'id': 'http://localhost/schemas/records/record-v1.0.0.json',
#  'additionalProperties': False,
#  'title': 'invenio-nyu v1.0.0',
#  'type': 'object',
#  'properties': {'$schema': {'description': 'The main JSON schema for the nyu-invenio project',
#    'type': 'string'},
#   '_bucket': {'description': 'UUID of the deposit bucket.', 'type': 'string'},
#   '_files': {'description': 'Describe information needed for files in records.',
#    'type': 'array',
#    'items': {'description': 'Describes the information of a single file in the record.',
#     'properties': {'key': {'description': 'Key (filename) of the file.',
#       'type': 'string'},
#      'file_id': {'description': 'UUID of the FileInstance object.',
#       'type': 'string'},
#      'bucket': {'description': 'UUID of the bucket to which this file is assigned.',
#       'type': 'string'},
# ...

# %%
record
# Out:
# {'access': {'files': 'public', 'record': 'public'},
#  'files': {'enabled': True},
#  'metadata': {'title': 'Piano Player and Saxophone Player',
#   'description': 'This photo is one of of 86 photos that represents locations of street art, graffiti, murals, and other scenes of the Black Lives Matter movement that took place in Soho, New York City in early-June, 2020. The images were captured in the days following the murder of George Floyd, who was killed while in police custody in Minneapolis, MN on May 25, 2020. Many images depict shuttered storefronts that have been covered with graffiti, murals, and artwork. These expressions constitute celebration of Black life and outrage for the violence and brutality Black people have experienced at the hands of the police. Please be advised that this collection contains images with profane words and epithets that are borne of race-based violence and hatred.',
#   'additional_descriptions': [{'description': 'UC-01',
#     'type': 'other',
# ...
